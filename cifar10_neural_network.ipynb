# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# Load and normalize the data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=20)

# Class names corresponding to the indices
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 
                'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Make predictions
predictions = model.predict(x_test)
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.2799 - loss: 1.9873
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3851 - loss: 1.7115
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4178 - loss: 1.6305
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4374 - loss: 1.5743
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4494 - loss: 1.5273
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4613 - loss: 1.5060
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4723 - loss: 1.4760
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4712 - loss: 1.4751
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4795 - loss: 1.4534
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4868 - loss: 1.4318
# Epoch 11/20
# ...

# %%
# Print prediction and actual label for the second test image
predicted_class_index = np.argmax(predictions[6])
predicted_class_name = class_names[predicted_class_index]

print('Prediction probabilities for the second test image:', predictions[6])
print('Predicted label for the second test image:', predicted_class_name)
print('Actual label for the second test image:', class_names[y_test[6][0]])
# Out:
# Prediction probabilities for the second test image: [1.0841413e-01 6.8598902e-01 7.8380071e-03 1.2132311e-01 3.6295922e-04
#  2.8423153e-02 9.2881377e-04 1.3537928e-03 4.0898550e-02 4.4684168e-03]
# Predicted label for the second test image: Automobile
# Actual label for the second test image: Automobile

# %%
# Display the first test image
plt.imshow(x_test[6])
plt.title(f'Predicted: {class_names[np.argmax(predictions[6])]}'
          f'\nActual: {class_names[y_test[6][0]]}')
plt.colorbar()
plt.show()
